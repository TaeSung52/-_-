# %%
import pandas as pd
df = pd.read_csv('생활인구_최종.csv')
df
# Out:
#            연월     행정동코드 시군구명   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0      202301  11110515  종로구  청운효자동  208800             9634            11075
# 1      202301  11110530  종로구    사직동  378960             6374            10358
# 2      202301  11110540  종로구    삼청동   81041             2946             6179
# 3      202301  11110550  종로구    부암동  144951             6911             6836
# 4      202301  11110560  종로구    평창동  185599             7851             8094
# ...       ...       ...  ...    ...     ...              ...              ...
# 13139  202507  11740650  강동구   성내2동  276466             7179             9795
# 13140  202507  11740660  강동구   성내3동  331010            16015            15285
# 13141  202507  11740685  강동구     길동  685665            21507            25518
# 13142  202507  11740690  강동구   둔촌1동  272515            16897             8956
# 13143  202507  11740700  강동구   둔촌2동  274002            12566            10017
#
# ...

# %%
import pandas as pd
df_2 = pd.read_csv('생활인구_2025.csv')
df_2
# Out:
#           연월     행정동코드   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0     202501  11110515  청운효자동  185095             8294             7116
# 1     202502  11110515  청운효자동  194910             7819             7123
# 2     202503  11110515  청운효자동  209789            12667             6856
# 3     202504  11110515  청운효자동  213643            13286             6780
# 4     202505  11110515  청운효자동  212746            13260             7002
# ...      ...       ...    ...     ...              ...              ...
# 5083  202508  11740700   둔촌2동  278445            11158            10385
# 5084  202509  11740700   둔촌2동  271233            10739             9109
# 5085  202510  11740700   둔촌2동  271318            10822             9115
# 5086  202511  11740700   둔촌2동  276882            11132             9457
# 5087  202512  11740700   둔촌2동  278407            10878             9816
#
#       남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  남자40세부터44세생활인구수  ...  \
# ...

# %%
df.drop_duplicates(subset=['행정동코드'], inplace=True)

# %%
df
# Out:
#          연월     행정동코드 시군구명   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0    202301  11110515  종로구  청운효자동  208800             9634            11075
# 1    202301  11110530  종로구    사직동  378960             6374            10358
# 2    202301  11110540  종로구    삼청동   81041             2946             6179
# 3    202301  11110550  종로구    부암동  144951             6911             6836
# 4    202301  11110560  종로구    평창동  185599             7851             8094
# ..      ...       ...  ...    ...     ...              ...              ...
# 419  202301  11740650  강동구   성내2동  280914             7341            10374
# 420  202301  11740660  강동구   성내3동  327924            15829            16465
# 421  202301  11740685  강동구     길동  640157            23475            25973
# 422  202301  11740690  강동구   둔촌1동   47284             2966             1977
# 423  202301  11740700  강동구   둔촌2동  294081            14809            11342
#
# ...

# %%
# Merge df_2 with df on '행정동코드' to add the '시군구명' column
df_2 = pd.merge(df_2, df[['행정동코드', '시군구명']], on='행정동코드', how='left')

# Display the updated df_2 DataFrame
display(df_2.head())
# Out:
#        연월     행정동코드   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0  202501  11110515  청운효자동  185095             8294             7116
# 1  202502  11110515  청운효자동  194910             7819             7123
# 2  202503  11110515  청운효자동  209789            12667             6856
# 3  202504  11110515  청운효자동  213643            13286             6780
# 4  202505  11110515  청운효자동  212746            13260             7002
#
#    남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  남자40세부터44세생활인구수  ...  \
# 0             9099             7422            11313             8917  ...
# 1             9060             8178            10898             9484  ...
# 2             9180             8488            11611             9661  ...
# 3             9368             8529            11835             9743  ...
# 4             9436             8464            11945             9587  ...
#
#    여자15세부터19세생활인구수  여자20세부터24세생활인구수  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# ...

# %%
df_2.columns
# Out:
# Index(['연월', '행정동코드', '행정동명', '총생활인구수', '남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
#        '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
#        '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
#        '남자55세부터59세생활인구수', '여자15세부터19세생활인구수', '여자20세부터24세생활인구수',
#        '여자25세부터29세생활인구수', '여자30세부터34세생활인구수', '여자35세부터39세생활인구수',
#        '여자40세부터44세생활인구수', '여자45세부터49세생활인구수', '여자50세부터54세생활인구수',
#        '여자55세부터59세생활인구수', '시군구명'],
#       dtype='object')

# %%
df_2 = df_2[['연월', '행정동코드', '시군구명', '행정동명', '총생활인구수', '남자15세부터19세생활인구수', '남자20세부터24세생활인구수',
       '남자25세부터29세생활인구수', '남자30세부터34세생활인구수', '남자35세부터39세생활인구수',
       '남자40세부터44세생활인구수', '남자45세부터49세생활인구수', '남자50세부터54세생활인구수',
       '남자55세부터59세생활인구수', '여자15세부터19세생활인구수', '여자20세부터24세생활인구수',
       '여자25세부터29세생활인구수', '여자30세부터34세생활인구수', '여자35세부터39세생활인구수',
       '여자40세부터44세생활인구수', '여자45세부터49세생활인구수', '여자50세부터54세생활인구수',
       '여자55세부터59세생활인구수']]

# %%
df_2
# Out:
#           연월     행정동코드 시군구명   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0     202501  11110515  종로구  청운효자동  185095             8294             7116
# 1     202502  11110515  종로구  청운효자동  194910             7819             7123
# 2     202503  11110515  종로구  청운효자동  209789            12667             6856
# 3     202504  11110515  종로구  청운효자동  213643            13286             6780
# 4     202505  11110515  종로구  청운효자동  212746            13260             7002
# ...      ...       ...  ...    ...     ...              ...              ...
# 5083  202508  11740700  강동구   둔촌2동  278445            11158            10385
# 5084  202509  11740700  강동구   둔촌2동  271233            10739             9109
# 5085  202510  11740700  강동구   둔촌2동  271318            10822             9115
# 5086  202511  11740700  강동구   둔촌2동  276882            11132             9457
# 5087  202512  11740700  강동구   둔촌2동  278407            10878             9816
#
# ...

# %%
df_2.to_csv('시군구명 있는 생활인구_2025.csv',index=False)

# %%
df = df[df['연월']<=202412]
df
# Out:
#            연월     행정동코드 시군구명   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0      202301  11110515  종로구  청운효자동  208800             9634            11075
# 1      202301  11110530  종로구    사직동  378960             6374            10358
# 2      202301  11110540  종로구    삼청동   81041             2946             6179
# 3      202301  11110550  종로구    부암동  144951             6911             6836
# 4      202301  11110560  종로구    평창동  185599             7851             8094
# ...       ...       ...  ...    ...     ...              ...              ...
# 10171  202412  11740650  강동구   성내2동  285450             7107             9995
# 10172  202412  11740660  강동구   성내3동  322605            14419            14908
# 10173  202412  11740685  강동구     길동  669372            19308            25238
# 10174  202412  11740690  강동구   둔촌1동  138174            10842             3984
# 10175  202412  11740700  강동구   둔촌2동  278436            12984             9743
#
# ...

# %%
people = pd.concat([df, df_2])
display(people.head())
display(people.tail())
# Out:
#        연월     행정동코드 시군구명   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0  202301  11110515  종로구  청운효자동  208800             9634            11075
# 1  202301  11110530  종로구    사직동  378960             6374            10358
# 2  202301  11110540  종로구    삼청동   81041             2946             6179
# 3  202301  11110550  종로구    부암동  144951             6911             6836
# 4  202301  11110560  종로구    평창동  185599             7851             8094
#
#    남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  ...  남자55세부터59세생활인구수  \
# 0             9806            10162            11253  ...             9933
# 1            18806            21297            27602  ...            18351
# 2             3869             4265             4904  ...             4222
# 3             6163             5355             7922  ...             8431
# 4             8505             6371             9131  ...            12138
#
# ...

# %%
people
# Out:
#           연월     행정동코드 시군구명   행정동명  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0     202301  11110515  종로구  청운효자동  208800             9634            11075
# 1     202301  11110530  종로구    사직동  378960             6374            10358
# 2     202301  11110540  종로구    삼청동   81041             2946             6179
# 3     202301  11110550  종로구    부암동  144951             6911             6836
# 4     202301  11110560  종로구    평창동  185599             7851             8094
# ...      ...       ...  ...    ...     ...              ...              ...
# 5083  202508  11740700  강동구   둔촌2동  278445            11158            10385
# 5084  202509  11740700  강동구   둔촌2동  271233            10739             9109
# 5085  202510  11740700  강동구   둔촌2동  271318            10822             9115
# 5086  202511  11740700  강동구   둔촌2동  276882            11132             9457
# 5087  202512  11740700  강동구   둔촌2동  278407            10878             9816
#
# ...

# %%
people.to_csv('생활인구_통합본.csv',index=False)
